# %%
#import libraries

import numpy as np
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import random
import re
import string

# %%
# #take a subsample of 600000 from the data to work with, since there are more than 1.2 million rows

# total_rows = 1264216
# sample_size = 600000
# skiprows = sorted(random.sample(range(total_rows), total_rows-sample_size))

# dtype = {'Id': pd.Int64Dtype(), 'OwnerUserId': pd.Int64Dtype(), 'CreationDate': np.datetime64, 'ClosedDate': np.datetime64, 'Title': object, 'Body': object}
# data = pd.read_csv('Questions.csv', engine='python', dtype=dtype, skiprows=skiprows)
# data.head()

# %%
# #get the respective tags for the selected subsample of the questions

# tags = pd.read_csv('Tags.csv')
# tags = tags[tags['Id'].isin(data['Id'])]
# tags.head()

# %%
# #select features to use

# features = ['Title', 'Body']
# X = data[features]

# %%
# #strip html tags from question body using beautifulsoup

# for i in range(500000, 600000):
#     X.iloc[i, 1] = BeautifulSoup(X.iloc[i, 1]).get_text()

# %%
# #convert to lower case

# for i in range(500000, 600000):
#     X.iloc[i, 0] = X.iloc[i, 0].lower()
#     X.iloc[i, 1] = X.iloc[i, 1].lower()

# %%
# #remove numbers

# for i in range(500000, 600000):
#     X.iloc[i, 0] = re.sub(r'\d+', '', X.iloc[i, 0])
#     X.iloc[i, 1] = re.sub(r'\d+', '', X.iloc[i, 1])

# %%
# #remove punctuation

# for i in range(500000, 600000):
#     X.iloc[i, 0] = X.iloc[i, 0].translate(X.iloc[i, 0].maketrans('', '', string.punctuation))
#     X.iloc[i, 1] = X.iloc[i, 1].translate(X.iloc[i, 1].maketrans('', '', string.punctuation))

# %%
# #remove whitespaces

# for i in range(250000, 600000):
#     X.iloc[i, 0] = X.iloc[i, 0].strip()
#     X.iloc[i, 1] = X.iloc[i, 1].strip()

# %%
# #remove stop words

# stopwords = set(nltk.corpus.stopwords.words('english'))

# for i in range(500000, 600000):
#     X.iloc[i, 0] = " ".join([word for word in nltk.tokenize.word_tokenize(X.iloc[i, 0]) if not word in stopwords])
#     X.iloc[i, 1] = " ".join([word for word in nltk.tokenize.word_tokenize(X.iloc[i, 1]) if not word in stopwords])

# %%
# #perform stemming

# stemmer = nltk.stem.SnowballStemmer('english')
# for i in range(500000, 600000):
#     X.iloc[i, 0] = " ".join([stemmer.stem(word) for word in nltk.tokenize.word_tokenize(X.iloc[i, 0])])
#     X.iloc[i, 1] = " ".join([stemmer.stem(word) for word in nltk.tokenize.word_tokenize(X.iloc[i, 1])])

# %%
#get count of all tags

tags_count = y.groupby('Tag')['Id'].nunique().sort_values(ascending=False).reset_index(name='count').head(10)

#select top 10 tags

tags_to_use = tags_count['Tag']

#extract question ids having these tags

question_ids = sorted(set(y[y['Tag'].isin(tags_to_use)]['Id']))

# %%
#get questions having the selected tags
X_top10tags = X[X['Id'].isin(question_ids)]

#get the word count of distinct words in title and body
word_features = {}
for i in range(X_top10tags.shape[0]):
    for word in nltk.tokenize.word_tokenize(X_top10tags.iloc[i, 0]):
        if word not in word_features:
            word_features[word] = 1
        else:
            word_features[word] += 1
    for word in nltk.tokenize.word_tokenize(X_top10tags.iloc[i, 1]):
        if word not in word_features:
            word_features[word] = 1
        else:
            word_features[word] += 1
# Out:
# {'use': 358044,
#  'nest': 6094,
#  'class': 178027,
#  'case': 42446,
#  'work': 176729,
#  'collect': 10073,
#  'video': 13040,
#  'playback': 449,
#  'record': 15213,
#  'one': 95464,
#  'main': 35846,
#  'act': 1902,
#  'like': 145662,
#  'public': 234192,
#  'interfac': 13558,
#  'method': 101052,
#  'play': 13317,
#  'stop': 14021,
#  'paus': 3206,
#  'etc': 16319,
#  'workhors': 6,
#  'decod': 2776,
#  'encod': 6620,
#  'learn': 7089,
#  'exist': 20670,
#  'c': 77901,
#  'im': 154543,
#  'curious': 1427,
#  'know': 67282,
#  'programm': 1610,
#  'think': 23677,
#  'littl': 7290,
#  'wari': 21,
#  'realli': 18395,
#  'sure': 24656,
#  'benefitsdrawback': 3,
#  'seem': 40070,
#  'accord': 6409,
#  'book': 6054,
#  'read': 39797,
#  'mine': 1473,
#  'suggest': 17351,
#  'scenario': 4156,
#  'good': 13909,
#  'solut': 28409,
#  'would': 93267,
#  'insid': 26950,
#  'separ': 10366,
#  'file': 189532,
#  'client': 26798,
#  'meant': 1012,
#  'avoid': 6753,
#  'possibl': 36612,
# ...

# %%
#select top K frequent words as features
word_features = sorted(word_features.items(), key=lambda item: item[1], reverse=True)
word_features_top25 = word_features[:25]
word_features_top25 = [item[0] for item in word_features_top25]

for word in word_features_top25:
    X_top10tags[word] = 0

# %%
#set feature values for each question
for i in range(300000, X_top10tags.shape[0]):
    for word in nltk.tokenize.word_tokenize(X_top10tags.iloc[i, 0]):
        if word in word_features_top25:
            X_top10tags.loc[X_top10tags.index[i], word] = 1
    for word in nltk.tokenize.word_tokenize(X_top10tags.iloc[i, 1]):
        if word in word_features_top25:
            X_top10tags.loc[X_top10tags.index[i], word] = 1
# Out:
# /home/virik/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# #save the dataframes as feathers

# data.to_feather('./data.ftr')
X.to_feather('./X.ftr')

# #sliced dataframe needs to be reindexed or converted to csv before saving as feather
# tags.to_csv('./tags.csv', index=False)
# tags = pd.read_csv('./tags.csv')
# tags.to_feather('./tags.ftr')

X_top10tags.to_csv('./X_10tags25features.csv', index=False)
X_10tags25features = pd.read_csv('./X_10tags25features.csv')
X_10tags25features.to_feather('./X_10tags25features.ftr')
